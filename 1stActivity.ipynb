# %% [markdown]
# <a href="https://colab.research.google.com/github/espanolamarie/BSIS-2A-/blob/main/1stActivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('https://raw.githubusercontent.com/espanolamarie/BSIS-2A-/main/example.csv')

# %%
df.head(2)
# Out:
#    age   income  gender  purchased
# 0   32      NaN    male        1.0
# 1   23  12323.0  female        1.0

# %%
df.tail(1)
# Out:
#    age  income  gender  purchased
# 5   12  2312.0  female        1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6 non-null      int64
#  1   income     5 non-null      float64
#  2   gender     4 non-null      object
#  3   purchased  5 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#              age        income  purchased
# count   6.000000      5.000000   5.000000
# mean   29.500000  14985.200000   0.800000
# std    12.565827  22519.713924   0.447214
# min    12.000000   1345.000000   0.000000
# 25%    23.000000   2312.000000   1.000000
# 50%    27.500000   4423.000000   1.000000
# 75%    40.250000  12323.000000   1.000000
# max    44.000000  54523.000000   1.000000

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['age', 'income', 'gender', 'purchased'], dtype='object')

# %%
df= df.drop('gender', axis =1)

# %%
df.head()
# Out:
#    age   income  purchased
# 0   32      NaN        1.0
# 1   23  12323.0        1.0
# 2   23   4423.0        0.0
# 3   44   1345.0        NaN
# 4   43  54523.0        1.0

# %%
df_filna = df.fillna('n/a')

# %%
df_filna.head()
# Out:
#    age   income purchased
# 0   32      n/a       1.0
# 1   23  12323.0       1.0
# 2   23   4423.0       0.0
# 3   44   1345.0       n/a
# 4   43  54523.0       1.0

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    age   income  purchased
# 1   23  12323.0        1.0
# 2   23   4423.0        0.0
# 4   43  54523.0        1.0
# 5   12   2312.0        1.0

# %%
df_sort = df.sort = df.sort_value(by ='gender',asceding = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-3d71c0917a86> in <cell line: 1>()
# ----> 1 df_sort = df.sort = df.sort_value(by ='gender',asceding = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'
